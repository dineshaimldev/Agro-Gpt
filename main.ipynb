# %% [markdown]
# <a href="https://colab.research.google.com/github/dineshaimldev/Agro-Gpt/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
my_torch = torch.arange(10)
my_torch

# %%
my_torch = my_torch.reshape(2,5)
my_torch

# %%
my_torch2 = torch.arange(10)
my_torch2

# %%
my_torch3 = my_torch2.view(2,5)
my_torch3

# %%
my_torch4 = torch.arange(10)
my_torch4

# %%
my_torch4[2] = 121
my_torch4

# %%
my_torch4 = my_torch4.reshape(2,5)
my_torch4

# %%
my_torch5 = torch.arange(10)
my_torch5

# %%
my_torch5[5]

# %%
my_torch5 = my_torch5.reshape(5,2)
my_torch5

# %%
my_torch5[:,1]

# %%
my_torch5[:,:1]
